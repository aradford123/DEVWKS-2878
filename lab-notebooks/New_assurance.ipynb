# %% [markdown]
# # Assurance API for DNA-Center

# %%
from util import get_url
import json
import time

# %%
response = get_url("dna/intent/api/v1/network-health?timestamp=", headers={})
# Out:
# https://sandboxdnac2.cisco.com:8080/dna/intent/api/v1/network-health?timestamp=

# %%
print (json.dumps(response, indent=2))
# Out:
# {
#   "latestMeasuredByEntity": null,
#   "healthDistirubution": [
#     {
#       "category": "Access",
#       "badPercentage": 0,
#       "unmonPercentage": 0,
#       "fairPercentage": 0,
#       "fairCount": 0,
#       "totalCount": 2,
#       "kpiMetrics": [],
#       "goodCount": 2,
#       "healthScore": 100,
#       "goodPercentage": 100,
#       "unmonCount": 0,
#       "badCount": 0
#     },
#     {
#       "category": "Distribution",
#       "badPercentage": 0,
#       "unmonPercentage": 0,
#       "fairPercentage": 0,
#       "fairCount": 0,
#       "totalCount": 1,
#       "kpiMetrics": [],
#       "goodCount": 1,
#       "healthScore": 100,
#       "goodPercentage": 100,
#       "unmonCount": 0,
#       "badCount": 0
#     },
#     {
#       "category": "WLC",
#       "badPercentage": 0,
#       "unmonPercentage": 0,
#       "fairPercentage": 0,
#       "fairCount": 0,
#       "totalCount": 1,
#       "kpiMetrics": [],
#       "goodCount": 1,
#       "healthScore": 100,
#       "goodPercentage": 100,
#       "unmonCount": 0,
#       "badCount": 0
#     },
#     {
#       "category": "AP",
#       "badPercentage": 0,
#       "unmonPercentage": 14.285714,
#       "fairPercentage": 0,
#       "fairCount": 0,
#       "totalCount": 7,
#       "kpiMetrics": [],
#       "goodCount": 6,
#       "healthScore": 86,
#       "goodPercentage": 85.71429,
#       "unmonCount": 1,
#       "badCount": 0
#     }
#   ],
#   "measuredBy": "global",
#   "version": "1.0",
#   "latestHealthScore": 91,
#   "monitoredHealthyDevices": 10,
#   "monitoredUnHealthyDevices": 0,
#   "response": [
#     {
#       "timeinMillis": 1551513300000,
#       "time": "2019-03-02T07:55:00.000+0000",
#       "fairCount": 0,
#       "entity": null,
#       "totalCount": 11,
#       "goodCount": 10,
#       "healthScore": 91,
#       "unmonCount": 1,
#       "badCount": 0
#     }
#   ],
#   "monitoredDevices": 10,
#   "unMonitoredDevices": 1
# }

# %%
response = get_url("dna/intent/api/v1/client-health?timestamp=", headers={})
# Out:
# https://sandboxdnac2.cisco.com:8080/dna/intent/api/v1/client-health?timestamp=

# %%
print(json.dumps(response, indent=2))
# Out:
# {
#   "response": [
#     {
#       "scoreDetail": [
#         {
#           "scoreValue": 40,
#           "clientUniqueCount": 5,
#           "scoreCategory": {
#             "scoreCategory": "CLIENT_TYPE",
#             "value": "ALL"
#           },
#           "starttime": 1551518880000,
#           "clientCount": 5,
#           "endtime": 1551519180000,
#           "scoreList": []
#         },
#         {
#           "scoreValue": 100,
#           "clientUniqueCount": 2,
#           "scoreCategory": {
#             "scoreCategory": "CLIENT_TYPE",
#             "value": "WIRED"
#           },
#           "starttime": 1551518880000,
#           "clientCount": 2,
#           "endtime": 1551519180000,
#           "scoreList": [
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "POOR"
#               },
#               "starttime": 1551518880000,
#               "clientCount": 0,
#               "endtime": 1551519180000,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "FAIR"
#               },
#               "starttime": 1551518880000,
#               "clientCount": 0,
#               "endtime": 1551519180000,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "GOOD"
#               },
#               "starttime": 1551518880000,
#               "clientCount": 2,
#               "endtime": 1551519180000,
#               "scoreList": [
#                 {
#                   "scoreValue": -1,
#                   "clientUniqueCount": null,
#                   "scoreCategory": {
#                     "scoreCategory": "deviceType",
#                     "value": "ALL"
#                   },
#                   "starttime": 1551518880000,
#                   "clientCount": 2,
#                   "endtime": 1551519180000,
#                   "scoreList": []
#                 }
#               ]
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "IDLE"
#               },
#               "starttime": 1551518880000,
#               "clientCount": 0,
#               "endtime": 1551519180000,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "NODATA"
#               },
#               "starttime": 1551518880000,
#               "clientCount": 0,
#               "endtime": 1551519180000,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "NEW"
#               },
#               "starttime": 1551518880000,
#               "clientCount": 0,
#               "endtime": 1551519180000,
#               "scoreList": []
#             }
#           ]
#         },
#         {
#           "scoreValue": 0,
#           "clientUniqueCount": 3,
#           "scoreCategory": {
#             "scoreCategory": "CLIENT_TYPE",
#             "value": "WIRELESS"
#           },
#           "starttime": 1551518880000,
#           "clientCount": 3,
#           "endtime": 1551519180000,
#           "scoreList": [
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "POOR"
#               },
#               "starttime": 1551518880000,
#               "clientCount": 0,
#               "endtime": 1551519180000,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "FAIR"
#               },
#               "starttime": 1551518880000,
#               "clientCount": 3,
#               "endtime": 1551519180000,
#               "scoreList": [
#                 {
#                   "scoreValue": -1,
#                   "clientUniqueCount": null,
#                   "scoreCategory": {
#                     "scoreCategory": "deviceType",
#                     "value": "ALL"
#                   },
#                   "starttime": 1551518880000,
#                   "clientCount": 3,
#                   "endtime": 1551519180000,
#                   "scoreList": []
#                 }
#               ]
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "GOOD"
#               },
#               "starttime": 1551518880000,
#               "clientCount": 0,
#               "endtime": 1551519180000,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "IDLE"
#               },
#               "starttime": 1551518880000,
#               "clientCount": 0,
#               "endtime": 1551519180000,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "NODATA"
#               },
#               "starttime": 1551518880000,
#               "clientCount": 0,
#               "endtime": 1551519180000,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "NEW"
#               },
#               "starttime": 1551518880000,
#               "clientCount": 0,
#               "endtime": 1551519180000,
#               "scoreList": []
#             }
#           ]
#         }
#       ],
#       "siteId": "global"
#     }
#   ]
# }

# %%
response = get_url("dna/intent/api/v1/network-health?timestamp=", headers={})
# Out:
# https://sandboxdnac2.cisco.com:8080/dna/intent/api/v1/network-health?timestamp=

# %%
print(json.dumps(response, indent=2))
# Out:
# {
#   "latestMeasuredByEntity": null,
#   "healthDistirubution": [
#     {
#       "category": "Access",
#       "badPercentage": 0,
#       "unmonPercentage": 0,
#       "fairPercentage": 0,
#       "fairCount": 0,
#       "totalCount": 2,
#       "kpiMetrics": [],
#       "goodCount": 2,
#       "healthScore": 100,
#       "goodPercentage": 100,
#       "unmonCount": 0,
#       "badCount": 0
#     },
#     {
#       "category": "Distribution",
#       "badPercentage": 0,
#       "unmonPercentage": 0,
#       "fairPercentage": 0,
#       "fairCount": 0,
#       "totalCount": 1,
#       "kpiMetrics": [],
#       "goodCount": 1,
#       "healthScore": 100,
#       "goodPercentage": 100,
#       "unmonCount": 0,
#       "badCount": 0
#     },
#     {
#       "category": "WLC",
#       "badPercentage": 0,
#       "unmonPercentage": 0,
#       "fairPercentage": 0,
#       "fairCount": 0,
#       "totalCount": 1,
#       "kpiMetrics": [],
#       "goodCount": 1,
#       "healthScore": 100,
#       "goodPercentage": 100,
#       "unmonCount": 0,
#       "badCount": 0
#     },
#     {
#       "category": "AP",
#       "badPercentage": 0,
#       "unmonPercentage": 14.285714,
#       "fairPercentage": 0,
#       "fairCount": 0,
#       "totalCount": 7,
#       "kpiMetrics": [],
#       "goodCount": 6,
#       "healthScore": 86,
#       "goodPercentage": 85.71429,
#       "unmonCount": 1,
#       "badCount": 0
#     }
#   ],
#   "measuredBy": "global",
#   "version": "1.0",
#   "latestHealthScore": 91,
#   "monitoredHealthyDevices": 10,
#   "monitoredUnHealthyDevices": 0,
#   "response": [
#     {
#       "timeinMillis": 1551519300000,
#       "time": "2019-03-02T09:35:00.000+0000",
#       "fairCount": 0,
#       "entity": null,
#       "totalCount": 11,
#       "goodCount": 10,
#       "healthScore": 91,
#       "unmonCount": 1,
#       "badCount": 0
#     }
#   ],
#   "monitoredDevices": 10,
#   "unMonitoredDevices": 1
# }

# %%
timestamp=1551513120000

# %%
response = get_url("dna/intent/api/v1/client-detail?timestamp={}&macAddress=F0:25:72:2A:D2:41".format(timestamp), headers={})
# Out:
# https://sandboxdnac2.cisco.com:8080/dna/intent/api/v1/client-detail?timestamp=1551513120000&macAddress=F0:25:72:2A:D2:41

# %%
print(json.dumps(response, indent=2))
# Out:
# {
#   "connectionInfo": {},
#   "detail": {
#     "errorCode": 5000,
#     "message": "An internal has error occurred while processing this request.",
#     "detail": "An internal has error occurred while processing this request."
#   },
#   "topology": {
#     "nodes": [
#       {
#         "count": null,
#         "connectedDevice": null,
#         "fabricGroup": null,
#         "nodeType": "Interface",
#         "description": "Client",
#         "family": null,
#         "radioFrequency": null,
#         "platformId": null,
#         "ip": "10.10.20.83",
#         "clients": null,
#         "userId": null,
#         "softwareVersion": null,
#         "deviceType": "UNKNOWN",
#         "healthScore": 10,
#         "role": "Client",
#         "level": 0,
#         "id": "F0_25_72_2A_D2_41",
#         "name": ""
#       },
#       {
#         "count": null,
#         "connectedDevice": null,
#         "fabricGroup": null,
#         "nodeType": "NetworkDevice",
#         "description": "SWITCH",
#         "family": "Switches and Hubs",
#         "radioFrequency": null,
#         "platformId": "C9300-48U",
#         "ip": "10.10.20.81",
#         "clients": 2,
#         "userId": null,
#         "softwareVersion": "16.6.3",
#         "deviceType": "Cisco Catalyst 9300 Switch",
#         "healthScore": 10,
#         "role": "ACCESS",
#         "level": 1,
#         "id": "6a49c827-9b28-490b-8df0-8b6c3b582d8a",
#         "name": "leaf1.labb.local"
#       }
#     ],
#     "links": [
#       {
#         "interfaceDetails": [],
#         "sourceInterfaceName": null,
#         "target": "6a49c827-9b28-490b-8df0-8b6c3b582d8a",
#         "targetInterfaceName": null,
#         "sourcePortMode": null,
#         "targetDuplexInfo": null,
#         "targetLinkStatus": null,
#         "label": [
#           "CLIENTDATA"
#         ],
#         "source": "F0_25_72_2A_D2_41",
#         "apRadioOperStatus": null,
#         "targetPortMode": null,
#         "apRadioAdminStatus": null,
#         "portUtilization": null,
#         "sourceLinkStatus": null,
#         "targetAdminStatus": null,
#         "sourceAdminStatus": null,
#         "linkStatus": "UP",
#         "id": null,
#         "sourceDuplexInfo": null
#       }
#     ]
#   }
# }

# %%
response = get_url("dna/intent/api/v1/client-detail?timestamp=&macAddress=00:00:2A:01:00:01", headers={})
# Out:
# https://sandboxdnac2.cisco.com:8080/dna/intent/api/v1/client-detail?timestamp=&macAddress=00:00:2A:01:00:01

# %%
print(json.dumps(response, indent=2))
# Out:
# {
#   "connectionInfo": {},
#   "detail": {
#     "errorCode": 5000,
#     "message": "An internal has error occurred while processing this request.",
#     "detail": "An internal has error occurred while processing this request."
#   },
#   "topology": {
#     "nodes": [
#       {
#         "count": null,
#         "connectedDevice": null,
#         "fabricGroup": null,
#         "nodeType": "Interface",
#         "description": "Client",
#         "family": null,
#         "radioFrequency": null,
#         "platformId": null,
#         "ip": "10.10.20.160",
#         "clients": null,
#         "userId": null,
#         "softwareVersion": null,
#         "deviceType": "Unclassified",
#         "healthScore": 4,
#         "role": "Client",
#         "level": 0,
#         "id": "00_00_2A_01_00_01",
#         "name": ""
#       },
#       {
#         "count": null,
#         "connectedDevice": null,
#         "fabricGroup": null,
#         "nodeType": "NetworkElement",
#         "description": "SSID",
#         "family": null,
#         "radioFrequency": "2.4 GHZ",
#         "platformId": null,
#         "ip": null,
#         "clients": null,
#         "userId": null,
#         "softwareVersion": null,
#         "deviceType": null,
#         "healthScore": null,
#         "role": "SSID",
#         "level": 1,
#         "id": "sandbox",
#         "name": "sandbox"
#       },
#       {
#         "count": null,
#         "connectedDevice": null,
#         "fabricGroup": null,
#         "nodeType": "NetworkDevice",
#         "description": "AP",
#         "family": "Unified AP",
#         "radioFrequency": null,
#         "platformId": "AIR-AP1141N-A-K9",
#         "ip": "10.10.20.241",
#         "clients": 3,
#         "userId": null,
#         "softwareVersion": "8.5.140.0",
#         "deviceType": "Cisco 1140 Unified Access Point",
#         "healthScore": 10,
#         "role": "ACCESS",
#         "level": 2,
#         "id": "8cd186fc-f86e-4123-86ed-fe2b2a41e3fc",
#         "name": "T1-1"
#       },
#       {
#         "count": null,
#         "connectedDevice": null,
#         "fabricGroup": null,
#         "nodeType": "NetworkDevice",
#         "description": "WLC",
#         "family": "Wireless Controller",
#         "radioFrequency": null,
#         "platformId": "AIR-CT3504-K9",
#         "ip": "10.10.20.51",
#         "clients": 3,
#         "userId": null,
#         "softwareVersion": "8.5.140.0",
#         "deviceType": "Cisco 3504 Wireless LAN Controller",
#         "healthScore": 10,
#         "role": "ACCESS",
#         "level": 3,
#         "id": "50c96308-84b5-43dc-ad68-cda146d80290",
#         "name": "3504_WLC"
#       }
#     ],
#     "links": [
#       {
#         "interfaceDetails": [],
#         "sourceInterfaceName": null,
#         "target": "sandbox",
#         "targetInterfaceName": null,
#         "sourcePortMode": null,
#         "targetDuplexInfo": null,
#         "targetLinkStatus": null,
#         "label": [
#           "CLIENTDATA"
#         ],
#         "source": "00_00_2A_01_00_01",
#         "apRadioOperStatus": null,
#         "targetPortMode": null,
#         "apRadioAdminStatus": null,
#         "portUtilization": null,
#         "sourceLinkStatus": null,
#         "targetAdminStatus": null,
#         "sourceAdminStatus": null,
#         "linkStatus": "UP",
#         "id": null,
#         "sourceDuplexInfo": null
#       },
#       {
#         "interfaceDetails": [],
#         "sourceInterfaceName": null,
#         "target": "8cd186fc-f86e-4123-86ed-fe2b2a41e3fc",
#         "targetInterfaceName": null,
#         "sourcePortMode": null,
#         "targetDuplexInfo": null,
#         "targetLinkStatus": null,
#         "label": [
#           "CLIENTDATA"
#         ],
#         "source": "sandbox",
#         "apRadioOperStatus": null,
#         "targetPortMode": null,
#         "apRadioAdminStatus": null,
#         "portUtilization": null,
#         "sourceLinkStatus": null,
#         "targetAdminStatus": null,
#         "sourceAdminStatus": null,
#         "linkStatus": "UP",
#         "id": null,
#         "sourceDuplexInfo": null
#       },
#       {
#         "interfaceDetails": [],
#         "sourceInterfaceName": null,
#         "target": "50c96308-84b5-43dc-ad68-cda146d80290",
#         "targetInterfaceName": null,
#         "sourcePortMode": null,
#         "targetDuplexInfo": null,
#         "targetLinkStatus": null,
#         "label": [
#           "CLIENTDATA",
#           "CAPWAPCTL"
#         ],
#         "source": "8cd186fc-f86e-4123-86ed-fe2b2a41e3fc",
#         "apRadioOperStatus": null,
#         "targetPortMode": null,
#         "apRadioAdminStatus": null,
#         "portUtilization": null,
#         "sourceLinkStatus": null,
#         "targetAdminStatus": null,
#         "sourceAdminStatus": null,
#         "linkStatus": "UP",
#         "id": null,
#         "sourceDuplexInfo": null
#       }
#     ]
#   }
# }
